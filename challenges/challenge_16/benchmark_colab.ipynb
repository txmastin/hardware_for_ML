# %% [markdown]
# # Feedforward NN Benchmark
# This notebook compares PyTorch, C (OpenBLAS), and CUDA implementations.

# %%
# Upload files
from google.colab import files
uploaded = files.upload()

# %%
# Compile and run C/OpenBLAS benchmark
# !gcc -O2 -lopenblas -o c_test c_test.c
# !./c_test

# %%
# Compile and run CUDA benchmark
# !nvcc -arch=sm_60 -O2 -lcublas -o cuda_test cuda_test.cu
# !./cuda_test

# %%
# Run PyTorch benchmark
# %run py_test.py
