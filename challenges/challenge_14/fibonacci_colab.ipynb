// %% [markdown]
// # 🔢 CUDA Fibonacci Benchmark on Google Colab
// This notebook compiles and runs three different Fibonacci implementations:
// - Naive CPU (sequential)
// - Linear GPU (CUDA single thread)
// - Parallel GPU (CUDA matrix exponentiation)

// %%
# ✅ Step 1: Upload the .cu file
from google.colab import files
uploaded = files.upload()

// %%
# ✅ Step 2: Compile and run the CUDA file
!nvcc -O2 -o fibbench fibonacci_benchmark.cu
!./fibbench
